# %% [markdown]
# # 04_pair_features
#
# Build pairwise features on the candidate set; inspect distributions (§6)
#
# Keep this notebook THIN - call into `src/business_entity_resolution/`, don't inline logic (CLAUDE.md §8, architecture.md §20 git-workflow note).

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
from business_entity_resolution.data.ingest import load_tsv, validate_schema
